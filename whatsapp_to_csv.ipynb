# %%
import re
import pandas as pd
import os
import sys

# %%
def get_date(message):
    """ This function is to get the date ONLY, doesn't include the time.
    
        Explanation:
        pattern1: [dd/MM/YY HH.MM.SS] Sender: Messages
                  [dd/MM/YY HH.MM.SS AM/PM] Sender: Messages
        pattern2: MM/dd/YY, HH:MM - Sender: Messages
                  MM/dd/YY, HH:MM AM/PM - Sender: Messages
        pattern3: dd/MM/YY HH.MM - Sender: Messages
        pattern4: dd/MM/YYYY HH.MM - Sender: Messages            # haven't met this pattern
    """
    pattern1 = r'\[(\d{1,2})\/(\d{1,2})\/(\d{1,2}) (\d{1,2})\.(\d{1,2})\.(\d{1,2})?( AM|PM)?\]'
    pattern2 = r'(\d{1,2})\/(\d{1,2})\/(\d{0,2})\, (\d{0,2}):(\d{1,2})( [A|P]M)? -'
    pattern3 = r'(\d{1,2})\/(\d{1,2})\/(\d{1,2}) (\d{1,2})\.(\d{1,2})'
    pattern4 = r'(\d{1,2})\/(\d{1,2})\/(\d{1,4}) (\d{1,2})\.(\d{1,2})'
    
    result1 = re.findall(pattern1, message)
    result2 = re.findall(pattern2, message)
    result3 = re.findall(pattern3, message)
    result4 = re.findall(pattern4, message)
    
    date = []
    if result1:
        for result in result1:
            date.append(result[0]+'/'+result[1]+'/'+result[2])
    elif result2:
        for result in result2:
            date.append(result[1]+'/'+result[0]+'/'+result[2])
    elif result3:
        for result in result3:
            date.append(result[0]+'/'+result[1]+'/'+result[2])
    elif result4:
        for result in result4:
            date.append(result[0]+'/'+result[1]+'/'+result[2])
    else:
        print("No pattern detected.")
    return date

# %%
def get_sender(message):
    """ This function is to get the sender from messages.
    
        patternNo where the sender is a phone number (contact hasn't been saved)
        patternNa where the sender is a name
    """
    patternNo = r'(\+[\d+\-\s].*):'
    patternNa = r'[\]|\-] ?([\w\.].*):'

    resultNo = re.findall(patternNo, message)
    resultNa = re.findall(patternNa, message)
    
    if resultNo:
        return resultNo
    elif resultNa:
        return resultNa

# %%
def get_messages(message):
    """ This function is to get the messages!
        iOS and Android type is different.
    
    """
    pattern = r': ([\d\w\s\W][^\[\]]+)' # messages pattern for iOS
    
    RE_EMOJI = re.compile("(["
                          "\U0001F1E0-\U0001F1FF"  # flags (iOS)
                          "\U0001F300-\U0001F5FF"  # symbols & pictographs
                          "\U0001F600-\U0001F64F"  # emoticons
                          "\U0001F680-\U0001F6FF"  # transport & map symbols
                          "\U0001F700-\U0001F77F"  # alchemical symbols
                          "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                          "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                          "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                          "\U0001FA00-\U0001FA6F"  # Chess Symbols
                          "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                          "\U00002702-\U000027B0"  # Dingbats
                          "])")
    
    message = RE_EMOJI.sub(r'', message)
    
    # iOS
    if message.startswith('['):
        message = " ".join(message.split()) # remove excess line
        message = " ".join(message.split('\u200e')) # remove idk what this is xixi
        message = re.findall(pattern, message)
    
    # Android
    else:
        message = message.replace('\n', '')
        message = "".join(re.split('\\n?\d{1,2}\/\d{1,2}\/\d{1,2}, ', message))
        message = re.split(r'\d{1,2}:\d{1,2} [A|P]M - [\w\s]+: ', message)
        if '' in message:
            message.remove('') 
    return message

# %%
def convert_to_csv(dataframe, messages):
    """ This function is to convert .txt files to .csv files.
        All files stored in dataset_csv/
    """
    path = 'dataset_csv/'
    
    if not os.path.exists(path):
        os.mkdir(path)
    
    file = 'dataset_csv/' + messages.replace('.txt', '.csv')
    dataframe.to_csv(file, index=False)

# %%
def create_df(message):
    """ Aggregate date, sender, and messages then create a Data Frame """
    date = get_date(message)
    sender = get_sender(message)
    messages = get_messages(message)
    df = pd.DataFrame(
            list(zip(date, sender, messages)),
            columns=['timestamp', 'sender', 'messages']
        )
    return df

# %%
def main():
    files = os.listdir(os.getcwd()+'/dataset')
    messages_list = [file for file in files if file.endswith('.txt')]
    
    for messages in messages_list: 
        with open('dataset/' + messages, encoding='utf-8') as file:
            message = file.read()
            
            df = create_df(message)
    return df
#             convert_to_csv(df, messages)

# %%
main()
# Out:
#     timestamp            sender  \
# 0     25/6/20  Franklid Gunawan
# 1     25/6/20          Pak Imam
# 2     25/6/20  Franklid Gunawan
# 3     13/8/20  Franklid Gunawan
# 4     14/8/20          Pak Imam
# ..        ...               ...
# 195   14/1/21  Franklid Gunawan
# 196   14/1/21          Pak Imam
# 197   14/1/21          Pak Imam
# 198   14/1/21          Pak Imam
# 199   14/1/21  Franklid Gunawan
#
#                                               messages
# 0    Selamat siang Pak Imam. Mohon maaf mengganggu ...
# 1    Baik Franklid, saya bersedia. Terkait judul, t...
# 2    Baik pak. Akan saya cari dan tambahkan. Terima...
# 3    Selamat siang Pak Imam. Mohon mqqf menggangu w...
# 4    Baik Franklid, saran saya Word Embeddingnya di...
# ..                                                 ...
# 195  Selamat siang pak. Mohon maaf mengganggu. Saya...
# 196  Baik Franklid, noted.Terkait 2.b, berdasarkan ...
# 197                                    <Media omitted>
# 198  Saran saya, sebaiknya ditambahkan variasi misa...
# 199  Baik pak, terima kasih atas sarannya. Akan seg...
#
# [200 rows x 3 columns]

# %%
with open(os.getcwd()+ '/dataset/kakmen.txt', encoding='utf-8') as file:
    message = file.read()

# %%
count=0
for m in message.split():
    if 'Gunawan:' in m:
        count += 1
print(count)
98+102
# Out:
# 102
# 200

# %%
print(len(get_date(message)), len(get_sender(message)), len(get_messages(message)))
# Out:
# 200 200 200

# %%
def get_messages(message):
    """ This function is to get the messages! """
    
    pattern = r'w+: ([\d\w\s\W]+) [A|P]M -' # messages pattern for iOS
    
    RE_EMOJI = re.compile("(["
                          "\U0001F1E0-\U0001F1FF"  # flags (iOS)
                          "\U0001F300-\U0001F5FF"  # symbols & pictographs
                          "\U0001F600-\U0001F64F"  # emoticons
                          "\U0001F680-\U0001F6FF"  # transport & map symbols
                          "\U0001F700-\U0001F77F"  # alchemical symbols
                          "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                          "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                          "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                          "\U0001FA00-\U0001FA6F"  # Chess Symbols
                          "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                          "\U00002702-\U000027B0"  # Dingbats
                          "])")
    
    message = RE_EMOJI.sub(r'', message)
    message = message.replace('\n', '')
    message = "".join(re.split('\\n?\d{1,2}\/\d{1,2}\/\d{1,2}, ', message))
    message = re.split(r'\d{1,2}:\d{1,2} [A|P]M - [\w\s]+: ', message)
    if '' in message:
        message.remove('')
#     message = " ".join(message.split('\u200e')) # remove idk what this is xixi
#     messages = re.findall(pattern, message)
    return message

# %%
get_messages(message)
# Out:
# [' Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. ',
#  'Assalamualaikum Wr. Wb. Selamat pagi Bu Indri, mohon maaf mengganggu waktunya. Perkenalkan nama saya Mentari Adiza (TIF’16) dengan keminatan KC. Saya salah satu mahasiswa bimbingan skripsi ibu. Saya ingin bertanya terkait pelaksanaan p0 skripsi saya. Saya sudah melaksanakan p0 dengan dosen 1 saya yakni Pak Imam. Kira-kira apakah ibu ada waktu untuk p0 pada hari ini sebagai dosen 2 saya bu? Terima kasih Bu untuk sebelum dan sesudahnya.. Wassalamualaikum ',
#  'Waalaikumsalam...iya bs 10.15-12.00 ',
#  'baik bu terima kasihh ',
#  'Assalamualaikum Wr. Wb. Selamat siang Bu, mohon maaf mengganggu waktunya. Saya ingin bertanya bu, kira-kira apakah ibu ada waktu untuk konsultasi terkait skripsi saya untuk hari ini? Terima kasih bu untuk sebelum dan sesudahnya.. Wassalamualaikum ',
#  'Waalaikumsalam wr wb... ',
#  'Iya ',
#  'maaf bu sebelumnya untuk pengiriman dokumen dan poin yang ingin ditanyakan bisa dikirim melalui media apa yaa bu? ',
#  'Wa saja ',
#  'baik bu.. ',
#  'Sebelumnya mohon maaf saya belum ada melakukan bimbingan lagi bu. Hal tersebut dikarenakan saya masih bingung dan berusaha mencari serta memahami langkah-langkah algoritma Kernel Extreme Learning Machine yang saya terapkan pada skripsi saya. Berikut beberapa poin revisi pada skripsi saya bu setelah konsultasi terakhir kita bu: Bab 1: - Latar belakang diberikan tambahan alasan menggunakan studi kasus saham PT. Telkom Bab 2: - Tambahan penjelasan bada bagian PER - Perubahan langkah-langkah algoritma KELM Bab 3: - Perubahan teknik analisis data - Perubahan flowchart KELM Bab 4: - Perubahan algoritma KELM - Perubahan flowchart KELM - Tambahan sebagian flowchart (belum selesai) - Tambahan manualisasi - Tambahan perancangan pengujian Ada beberapa poin yang ingin saya tanyakan. Mungkin sekiranya ibu berkenan memberikan masukan. Berikut pertanyaan saya: 1. Untuk pembentukan flowchart, tiap flowchart merepresentasikan satu method atau bagaimana yaa bu? 2. Untuk pengujian fungsi kernel, apakah perlu dijelaskan pada bab 3 tentang formulasi fungsi-fungsi kernel yang akan diuji? 3. Penginstansiasi nilai apakah perlu untuk dimasukkan ke flowchart bu? 4. Untuk method yang memiliki parameter, parameternya apakah dimasukkan ke flowchart sebagai data input? Sekian beberapa pertanyaan dari saya bu. Berikut saya lampirkan softcopy dari dokumen skripsi saya. Terima kasih bu untuk sebelum dan sesudahnya. Wassalamualaikum Wr. Wb.  ',
#  '165150200111171_Mentari Adiza P. Nst_Skripsi.docx •  52 pages  document omitted  ',
#  'Pembuatan Pseudocode, Flowchart.pdf •  14 pages  document omitted ',
#  'template flowchart ',
#  'mengenai metode silahkan tanya pembimbing 1 ya mbak...saya takut salah. Saya akan mengoreksi penulisan ',
#  'baik buu terima kasih banyakk ',
#  'Assalamualaikum Wr. Wb. Selamat pagi Bu, mohon maaf mengganggu waktunya. Saya ingin bertanya bu, kira-kira apakah ibu ada waktu untuk konsultasi terkait P1 skripsi saya untuk hari ini? Terima kasih bu untuk sebelum dan sesudahnya.. Wassalamualaikum ',
#  'ok ',
#  'Baik buu, berikut saya lampirkan softcopy dari dokumen skripsi saya, PPT P1, jurnal tekait, serta screenshoot sebagian program yang telah saya implementasikan. Terima kasih Bu..  ',
#  '165150200111171_Mentari Adiza P. Nst_Skripsi P1.rar  document omitted ',
#  'saya kirim file dengan format rar yaa bu, mungkin ibu ada masukan.. ',
#  'mengenai laporannya sudah sesuai tinggal melanjutkan ke bab selanjutnya ',
#  'untuk penilaian P1...saya blm bisa memasukkan nilai krn hr pembimbing 1 terlebih dahulu ',
#  'baik buu, nanti akan saya kabari lebih lanjut. terimakasih buu.. ',
#  'Assalamualaikum Wr. Wb Selamat siang bu Indri, mohon maaf mengganggu waktunya. Saya bermaksud ingin memberikan video presentasi P1 saya bu. Untuk video presentasinya sudah saya upload di GDrive bersama dengan dokumen P1 saya, berikut link-nya bu https://drive.google.com/drive/folders/1IiHH98bnrVlnA47_uDWLUPWR_lUSjJ7o?usp=sharing Terimakasih bu untuk sebelum dan sesudahnya Wassalamualaikum Wr. Wb ',
#  'Assalamualaikum Wr. Wb Minal ‘aidin wal faizin, mohon maaf lahir dan bathin yaa bu Selamat hari raya idul fitri bu.. ',
#  'Mohon maaf lahir dan batin jg ya... ',
#  'iyaa buu ',
#  'Assalamualaikum Wr. Wb. Selamat pagi Bu, mohon maaf mengganggu waktunya. Saya ingin bertanya bu, kira-kira apakah ibu ada waktu untuk konsultasi progress skripsi saya untuk hari ini? Terima kasih bu untuk sebelum dan sesudahnya.. Wassalamualaikum ',
#  'Waalaikumsalam..... Silahkan dikirim saja ',
#  'Tp saya koreksinya senin dpn ya ',
#  'Saya lagi koreksi nilai2 matkul hrs setor nilai ',
#  'baik buu tidak apa-apa, ini saya kirim dokumen skripsi dan hasil screenshoot programnya yaa bu  ',
#  'P2 v0.1.docx •  71 pages  document omitted  ',
#  'Screenshoot Program.docx •  4 pages  document omitted ',
#  'terimakasih buu ',
#  'Assalamualaikum Wr. Wb. Selamat pagi Bu, mohon maaf mengganggu waktunya. Saya ingin bertanya bu, kira-kira apakah ibu ada waktu untuk konsultasi progress skripsi saya untuk hari ini? Terima kasih bu untuk sebelum dan sesudahnya.. Wassalamualaikum ',
#  'waalaikumsalam ',
#  'ok ',
#  'baik buu, berikut saya lampirkan dokumen skripsi terakhir saya beserta screenshoot programnya  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Skripsi.docx •  83 pages  document omitted  ',
#  'Screenshoot Program.docx •  4 pages  document omitted ',
#  'terima kasih buu.. ',
#  'Untuk yg bab 5 penulisan kode program labelnya seharusnya kode program saja bukan Gambar ',
#  'Jd mis Kode Program 5.1 Normalisasi Data ',
#  'Jd labelnya dipisah dr gambar ',
#  'sehingga nanti ada daftar kode program ',
#  'yg lainnya sudah sesuai ',
#  'baik buu, segera saya perbaiki ',
#  'terimakasih bu Indrii.. ',
#  'Assalamualaikum Wr. Wb. Selamat siang Bu, mohon maaf mengganggu waktunya. Saya ingin bertanya bu, kira-kira apakah ibu ada waktu untuk konsultasi progress skripsi saya untuk hari ini? Terima kasih bu untuk sebelum dan sesudahnya.. Wassalamualaikum ',
#  'ok ',
#  'baik bu, berikut saya lampirkan dokumen skripsi terakhir saya beserta screenshoot kode programnya. saya kirim dengan format rar ya buu  ',
#  '165150200111171_Mentari Adiza P. Nst_Skripsi.rar  document omitted ',
#  'terima kasih bu.. ',
#  'Assalamualaikum bu, selamat sore. Mohon maaf bu saya ingin menanyakan revisi untuk dokumen skripsi saya yg terakhir apakah ada yang kurang buu? Terima kasih bu sebelumnya ',
#  'waalaikumsalam..... ',
#  'klo pengujian apakah tidak membutuhkan pengujian k-fold ',
#  '? ',
#  'silahkan dikonsultasikan ke pembimbing 1 dulu ',
#  'baik buu akan segera saya konsultasikan dengan dosen pembimbing 1 saya ',
#  'terima kasih buu ',
#  'Assalamualaikum Wr. Wb. Selamat sore bu Indri, mohon maaf mengganggu waktunya. Ada yg ingin saya tanyakan buu mengenai skripsi saya, apakah ibu ada waktuu? Terima kasih bu untuk sebelum dan sesudahnyaa ',
#  'Iya knapa? ',
#  'Pada skripsi saya Bab Kajian Pustaka, ada jurnal dari (Huang, et al) dengan judul Trends in Extreme Learning Machines A Review (terlampir), yang mana jurnal tersebut berisi ulasan dari penelitian-penelitian sebelumnya. Pada jurnal tersebut tidak dicantumkan data penelitiannya bu. Sehingga saya bingung untuk memasukkan objek pada kolom “Objek” di Tabel Kajian Pustaka saya (terlampir) bu. Apakah kira-kira ibu ada masukan?.. Terima kasih buu  ',
#  'Trends in Extreme Learning Machine - A Review.pdf •  17 pages  document omitted  ',
#  ' image omitted ',
#  'Dikosongi saja gpp ',
#  'baik buu terima kasihh ',
#  'Assalamualaikum Wr. Wb Selamat siang bu Indri, mohon maaf mengganggu waktunya. Saya bermaksud ingin memberikan progress skripsi saya, PPT P2, serta video presentasi P2 saya bu. Untuk video presentasinya sudah saya upload di GDrive bersama dengan dokumen P2 saya, berikut link-nya bu https://drive.google.com/drive/folders/1JQgBo8cTaWrSu0IviQ2fVxVWrlVfVXEl?usp=sharing Pada dokumen skripsi terbaru saya juga sudah ditambahkan pengujian K-Fold untuk data time series yg bernama Nested Cross Validation bu, berikut saya lampirkan dokumen saya untuk dapat ibu lihat. Terimakasih bu untuk sebelum dan sesudahnya Wassalamualaikum Wr. Wb  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Skripsi.docx •  158 pages  document omitted ',
#  'Ok saya cek dulu ',
#  'baik bu terima kasihh ',
#  'Assalamualaikum bu, maaf mengganggu waktunya. Saya ingin bertanya terkait skripsi saya bu.. Dari ibu sebagai pembimbing 2 saya, apakah saya sudah boleh untuk daftar seminar hasil untuk semester ini buu? Terima kasih buu sebelumnya ',
#  'waalaikumsalam... ',
#  'sdh saya periksa ',
#  'blh silahkan daftar saja ',
#  'baik buu terima kasih banyak yaa bu.. ',
#  'iya...tinggal turnitin laporannya sdh? ',
#  'Class ID 24371211 Enrollment key: skripsi2020 ',
#  'untuk dokumen P0-P2 sudah saya coba turnitin bu di induksi riset pak Imam. Untuk dokumen terakhir sebelum semhas belum saya upload ',
#  'baik buu segera saya upload di turnitinn ',
#  'Assalamualaikum bu, maaf mengganggu waktunya.. Saya ingin memberikan dokumen skripsi saya beserta screenshoot tes orisinalitas dari turnitin buu.  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Skripsi.docx •  159 pages  document omitted  ',
#  ' image omitted  ',
#  ' image omitted ',
#  'berikut filenya yaa bu ',
#  'Ok ',
#  'Klo ada yg perlu saya ttd i ',
#  'Silahkan kirim dlm bntk pdf ',
#  'Nanti saya ttd ',
#  'Baik ibuu terima kasih banyakk, untuk sementara belum ada penandatanganan kok buu ',
#  'Mohon maaf bu, untuk pengajuan penyelenggaraan semhas sudah saya ajukan di filkom apps yaa buu ',
#  'ok sdh ',
#  'baik buu terima kasihh ',
#  'Assalamualaikum Bu Indri, selamat siang.. Saya ingin memberikan undangan kepada ibu untuk menjadi fasilitator seminar hasil skripsi saya yang akan dilaksanakan pada Rabu, 15 Juli 2020 pukul 09.00-10.00 bu. Apakah ibu bersedia? Terima kasih buu sebelumnya.. Wassalamualaikum Wr. Wb ',
#  'ok ',
#  'baik buuu ',
#  'moga lancar ya....yg pntg perhatikan 8 poin penting yg hrs ada dislide ',
#  '[13/07/20 14.49.47',
#  'iyaa aamiinn makasih banyak yaa buu oiyaa bu mohon maaf 8 poin itu kira-kira apa saja yaa buu? ',
#  'Latar Belakang, Tujuan, Rumusan Masalah, Tinjauan Pustaka, Landasan Teori, Metodologi Penelitian, Pembahasan Hasil, Kesimpulan dan Saran ',
#  'Ohhh, baik buuu siappp. Terima kasih buu☺️ ',
#  'Assalamualaikum Wr. Wb, selamat pagi bu. maaf mengganggu waktunya.. Saya ingin bertanya bu, untuk seminar hasil saya pada hari ini apakah saya boleh mengirimkan kepada ibu dokumen skripsi serta jurnal terbaru dari saya bu? Soalnya saya menemukan ada kesalahan pada dokumen skripsi dan jurnal yg saya kirimkan melalui filkom apps bu.. Terima kasih bu sebelumnya, Wassalamualaikum Wr. Wb ',
#  'meet.google.com/ggx-coxx-poh ',
#  'ok ',
#  'baik buu, berikut saya lampirkan dokumennya beserta jurnalnya buu  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Skripsi.docx •  159 pages  document omitted  ',
#  'Jurnal J-PTIIK.docx •  7 pages  document omitted ',
#  'ini yg di apps brarti salah? nanti klo dah kluar jdwl sidang tlg di kirim ke penguji lg ya ',
#  'sdh sesuai... ',
#  'iya buuu ada kesalahan, baik buuu nanti saya kirimkan ke penguji juga ',
#  'terima kasih buu ',
#  'Assalamualaikum Wr. Wb. Selamat pagi bu, mohon maaf mengganggu waktunya. Saya bermaksud ingin memberitahukan pelaksanaan sidang skripsi saya pada Senin, 27 Juli 2020 pukul 08.00 dengan ibu sebagai Dosen Pembimbing 2. Apakah ibu bersedia menghadiri sidang tersebut? Terima kasih buu untuk sebelum dan sesudahnya.. Wassalamualaikum Wr. Wb ',
#  'Waalaikumsalam... Ok ',
#  'baik buu ',
#  'Assalamualaikum bu Indri, mohon maaf.. Saya ingin bertanya bu, pemberitahuan jika sudah boleh rejoin google meet lagi dapat dilihat dimana yaa bu?... ',
#  'Sdh ',
#  'Join lg ',
#  'baik buu terima kasihh ',
#  'Assalamualaikum Wr. Wb. Selamat siang Bu, mohon maaf mengganggu waktunya. Saya ingin memberikan revisi dokumen skripsi saya setelah pelaksanaan sidang bu. Berikut saya lampirkan dokumen skripsi terakhir saya. Terima kasih sebelumnya buu, Wassalamualaikum Wr. Wb  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Skripsi.docx •  157 pages  document omitted ',
#  'Sdh diberi tanda yg direvisi? ',
#  'belum buu ',
#  'sebentar saya berikan tanda ',
#  'Permisi buu, pada dokumen skripsi sudah saya berikan comment untuk tiap perubahan yaa bu. Berikut saya lampirkan juga poin revisinya. Revisi: - perubahan judul - penambahan lembar pengesahan - penambahan prakata - perubahan kata "syaraf" -> "saraf", "resiko" -> "risiko", "PT." -> "PT", "analisa" -> "analisis" - perubahan typo dan perubahan penulisan kata bahasa asing dengan cetak miring (italic) Bab 1: - perubahan penulisan latar belakang (hal. 2-3) - perubahan penulisan manfaat penelitian (hal. 3) Bab 2: - perubahan penulisan kajian pustaka dan penambahan satu tinjauan pustakan mengenai prediksi saham dengan KELM (hal. 6-10) - menghapus semua kalimat "sebagai berikut" setelah merujuk suatu persamaan, tabel, atau gambar (pada tiap persamaan, tabel, atau gambar) - pemindahan persamaan-persamaan fungsi kernel ke subbab Fungsi Kernel (hal. 18) Bab 4: - mengubah dan merapikan penulisan flowchart menjadi lebih mudah dipahami (hal. 26 - hal. 75) Bab 5: - merapikan penulisan kode program (hal. 87 - hal. 115)  ',
#  '165150200111171_Mentari Adiza P. Nst_Revisi Dokumen Skripsi.docx •  157 pages  document omitted  ',
#  '165150200111171_Mentari Adiza P. Nst_Revisi Dokumen Skripsi rev.docx  document omitted ',
#  'sdh saya komen ',
#  'baik buu terima kasihh ',
#  'Assalamualaikum Wr. Wb. Selamat siang bu Indri. Mohon maaf mengganggu waktunya. Saya ingin memberikan revisi dokumen skripsi saya lagi buu. Berikut saya lampirkan poin revisinya yaa bu. Revisi: - perubahan NIK pada bu Indriati menjadi NIP pada lembar pengesahan - perubahan urutan penulisan pada prakata - perubahan urutan ke-3 pada proses training (hal. 16) - perubahan gambar pada pengujian Nested Cross Validation menjadi bentuk shape (hal. 20 - hal. 21) - perubahan peletakan label kode program menjadi di bawah objek (hal. 87- hal. 115) Berikut saya lampirkan juga softcopy dari dokumen skripsi saya. Terima kasih buu sebelumnya Wassalamualaikum Wr. Wb.  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Skripsi.docx •  157 pages  document omitted ',
#  'Ok sip ',
#  'Dr saya ok ',
#  'baik buu terima kasihh ',
#  'Assalamualaikum Wr. Wb. Selamat pagi buu mohon maaf menganggu waktunya. Saya bermaksud ingin meminta tanda tangan ibu pada lembar pengesahan, berikut saya lampirkan yaa bu.  ',
#  'Mentari - Lembar Pengesahan-signed Fix.pdf •  1 page  document omitted ',
#  'terima kasih buu sebelumnyaa. Wassalamualaikum Wr. Wb  ',
#  'Mentari - Lembar Pengesahan-signed Fix.pdf •  1 page  document omitted ',
#  'baik buu terima kasih banyakk ',
#  'Assalamualaikum Wr. Wb. Selamat pagi bu, mohon maaf mengganggu waktunya. Saya bermaksud ingin meminta persetujuan ibu terkait dokumen skripsi yang sudah saya upload di filkomapps. Saya juga ingin menyerahkan jurnal dan meminta tanda tangan untuk form SC2-18 bu. Apakah sekiranya ibu ada waktuu? Terima kasih buu untuk sebelum dan sesudahnya, Wassalamualaikum Wr. Wb ',
#  'ok kirim aja dlm format pdf ',
#  'baik buu berikut form sc2-18nya  ',
#  'SC2-18.pdf •  1 page  document omitted ',
#  'saya lampirkan juga dokumen skripsi saya serta jurnal dan source codenya yaa buu  ',
#  '165150200111171_Mentari Adiza P. Nst_Dokumen Yudisium.rar  document omitted ',
#  'Ndak perlu... Sdhdiupload di apps kan ya? ',
#  'mohon maaf bu udah terlanjur terkirim.. ',
#  'sudah buu, tapi jurnalnya belum ',
#  'mungkin ibu ada revisi terkait jurnal saya buu? ',
#  'Gpp  ',
#  'SC2-18 (3).pdf •  1 page  document omitted ',
#  'Ok coba kirim ',
#  'baik buu terima kasih banyakk  ',
#  'Jurnal J-PTIIK.docx •  7 pages  document omitted ',
#  'ini jurnalnya bu  ',
#  ' image omitted ',
#  'baik buu  ',
#  ' image omitted  ',
#  ' image omitted ',
#  'Digabung dgn keterangan yg lain  ',
#  ' image omitted ',
#  'Mohon di cek kembali ya ',
#  'baik buu terima kasih untuk reviewnyaa☺️  ',
#  ' image omitted ',
#  'baikk bu segera saya perbaiki ',
#  'siang buu, berikut dokumen jurnal yg telah saya perbaiki..  ',
#  'Jurnal J-PTIIK.docx •  7 pages  document omitted ',
#  'jika berkenan mohon dikoreksi ulang buu, terima kasihh..  ',
#  ' image omitted  ',
#  ' image omitted ',
#  'Saya buka d hape ',
#  'Coba di cek lg di laptop ',
#  'oiyaa bu mohon maaf, ini yg sudah saya perbaiki lagi buu  ',
#  'Jurnal J-PTIIK.docx •  7 pages  document omitted  ',
#  ' image omitted ',
#  'untuk space kosong kalau dilihat dari laptop tidak terlalu banyak buu  ',
#  ' image omitted ',
#  'Oh ok ',
#  'Brarti beres ',
#  '[09/09/20 15.22.34',
#  'baik ibuu terima kasih yaa bu☺️ ',
#  'Assalamualaikum Wr. Wb. Selamat siang bu, mohon maaf mengganggu waktunya. Saya bermaksud ingin meminta persetujuan ibu terkait form SC2-16 dan form SC2-17. Apakah sekiranya ibu ada waktu untuk persetujuan dan penandatanganan buu? Terima kasih buu, Wassalamualaikum Wr. Wb ',
#  'ok ',
#  'baik bu berikut saya kirimkan formnya yaa bu  ',
#  'SC2-16.pdf •  2 pages  document omitted  ',
#  'SC2-17.pdf •  2 pages  document omitted  ',
#  'SC2-16 (4).pdf •  2 pages  document omitted  ',
#  'SC2-17 (6).pdf •  2 pages  document omitted ',
#  'terima kasih banyak buu ',
#  'Assalamualaikum buu, mohon maaf mengganggu waktunya jam segini buu tadi saya menelfon karena tidak sengaja kepencett.. Maaf yaa buuu ',
#  'Iya... Gpp sdh kuduga kok... ',
#  'hehehe iyaa buu maaf yaa bu sekali lagii ',
#  'selamat istirahat buu ',
#  'Assalamualaikum Wr. Wb. Selamat siang bu Indri, mohon maaf mengganggu waktunya. Saya hanya ingin menyampaikan terima kasih yg sebesar-besarnya untuk bimbingan ibu selama ini, saya sadar tanpa ibu saya tidak mungkin dapat menyelesaikan skripsi saya dengan baik. Semoga ibu dan keluarga diberi kesehatan yaa buu, aamiin YRA. Tetap semangat buu dalam mendidik dan membimbing kami yg ga tau apa-apa ini Wassalamualaikum Wr. Wb ',
#  'aamiin...sama2 mbak. Smoga sukses terus setelah lulus ... ',
#  'iyaa terima kasihh buu hehehe☺️']
